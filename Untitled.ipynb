# %%
python
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 python
#
# NameError: name 'python' is not defined

# %%
pip install cryptography matplotlib python-docx

# %%
# !python main.py
# Out:
# ^C

# %%
# %cd FILE_ENCRYPTION_AND_DECRYPTION
# Out:
# [WinError 2] The system cannot find the file specified: 'FILE_ENCRYPTION_AND_DECRYPTION'
# C:\Users\saura\FILE_ENCRYPTION_AND_DECRYPTION

# %%
# %cd "C:\Users\saura\FILE_ENCRYPTION_AND_DECRYPTION"
# Out:
# C:\Users\saura\FILE_ENCRYPTION_AND_DECRYPTION

# %%
import os
print(os.listdir())
# Out:
# ['.ipynb_checkpoints', 'auth.py', 'crypto.py', 'db.py', 'EncryptEase_Phase3_Report.docx', 'encrypt_ease.db', 'generate_report.py', 'gui.py', 'integrity.py', 'main.py', 'performance.py', 'test_performance_graph.py', 'Untitled.ipynb', 'untitled.txt', 'users.json', '__pycache__']

# %%
import importlib

for mod in ["auth", "crypto", "integrity", "performance"]:
    try:
        importlib.import_module(mod)
        print(f"✅ {mod}.py loaded successfully")
    except Exception as e:
        print(f"❌ {mod}.py has an error:", e)
# Out:
# ✅ auth.py loaded successfully
# ✅ crypto.py loaded successfully
# ✅ integrity.py loaded successfully
# ✅ performance.py loaded successfully

# %%
import importlib

for mod in ["auth", "crypto", "integrity", "performance"]:
    try:
        importlib.import_module(mod)
        print(f"✅ {mod}.py loaded successfully")
    except Exception as e:
        print(f"❌ {mod}.py has an error:", e)
# Out:
# ✅ auth.py loaded successfully
# ✅ crypto.py loaded successfully
# ✅ integrity.py loaded successfully
# ✅ performance.py loaded successfully

# %%
# temporary test
import crypto, hashlib

key = hashlib.sha256(b"demo").digest()
data = b"Hello EncryptEase"
enc = crypto.encrypt_aes(key, data)
dec = crypto.decrypt_aes(key, enc)
print("Original:", data)
print("Decrypted:", dec)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 6
#       4 key = hashlib.sha256(b"demo").digest()
#       5 data = b"Hello EncryptEase"
# ----> 6 enc = crypto.encrypt_aes(key, data)
#       7 dec = crypto.decrypt_aes(key, enc)
#       8 print("Original:", data)
#
# AttributeError: module 'crypto' has no attribute 'encrypt_aes'

# %%
# !python main.py

# %%
# !python main.py

# %%
# !python main.py

# %%
pip install cryptography matplotlib

# %%
# !python main.py

# %%
pip install cryptography matplotlib python-docx
